# %% [markdown]
# # Google Play Store EDA - Outputs Only

# %% [markdown]
# ### 1. Top Categories by Number of Apps
# ![top_categories.png](attachment:top_categories.png)

# %% [markdown]
# ### 2. Distribution of App Ratings
# ![rating_distribution.png](attachment:rating_distribution.png)

# %% [markdown]
# ### 3. Free vs Paid Apps
# ![free_paid_pie.png](attachment:free_paid_pie.png)

# %% [markdown]
# ### 4. Log(Installs) Distribution
# ![installs_log_hist.png](attachment:installs_log_hist.png)

# %% [markdown]
# ### 5. Rating Distribution by Category (Top 8 Categories)
# ![box_ratings_by_category.png](attachment:box_ratings_by_category.png)

# %% [markdown]
# ### 6. Reviews vs Installs (log-log)
# ![reviews_vs_installs.png](attachment:reviews_vs_installs.png)

# %% [markdown]
# ### 7. Rating vs Installs
# ![rating_vs_installs.png](attachment:rating_vs_installs.png)

# %% [markdown]
# ### 8. Top 20 Apps by Installs
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>App</th>
#       <th>Category</th>
#       <th>Installs</th>
#       <th>Rating</th>
#       <th>Reviews</th>
#       <th>Type</th>
#       <th>Price_USD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>App_1657</td>
#       <td>TOOLS</td>
#       <td>10000000</td>
#       <td>4.283599</td>
#       <td>691</td>
#       <td>Free</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>App_2894</td>
#       <td>FAMILY</td>
#       <td>10000000</td>
#       <td>4.471238</td>
#       <td>390</td>
#       <td>Free</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>App_1806</td>
#       <td>HEALTH</td>
#       <td>10000000</td>
#       <td>4.092844</td>
#       <td>23</td>
#       <td>Free</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>App_937</td>
#       <td>EDUCATION</td>
#       <td>10000000</td>
#       <td>4.487132</td>
#       <td>5266</td>
#       <td>Free</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>App_1824</td>
#       <td>HEALTH</td>
#       <td>10000000</td>
#       <td>4.350575</td>
#       <td>4</td>
#       <td>Free</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>App_1159</td>
#       <td>GAME</td>
#       <td>10000000</td>
#       <td>4.300676</td>
#       <td>545</td>
#       <td>Free</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>App_3635</td>
#       <td>ENTERTAINMENT</td>
#       <td>10000000</td>
#       <td>4.087687</td>
#       <td>374</td>
#       <td>Free</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>App_1848</td>
#       <td>EDUCATION</td>
#       <td>10000000</td>
#       <td>3.449784</td>
#       <td>273</td>
#       <td>Free</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>App_4601</td>
#       <td>MUSIC</td>
#       <td>10000000</td>
#       <td>4.096338</td>
#       <td>2136</td>
#       <td>Free</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>App_1852</td>
#       <td>SHOPPING</td>
#       <td>10000000</td>
#       <td>3.986067</td>
#       <td>1450</td>
#       <td>Free</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>App_1863</td>
#       <td>ENTERTAINMENT</td>
#       <td>10000000</td>
#       <td>4.154700</td>
#       <td>149</td>
#       <td>Free</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>App_4608</td>
#       <td>EDUCATION</td>
#       <td>10000000</td>
#       <td>3.568399</td>
#       <td>1320</td>
#       <td>Free</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>App_1876</td>
#       <td>LIFESTYLE</td>
#       <td>10000000</td>
#       <td>3.600073</td>
#       <td>400</td>
#       <td>Free</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>App_341</td>
#       <td>ENTERTAINMENT</td>
#       <td>10000000</td>
#       <td>4.489242</td>
#       <td>1156</td>
#       <td>Paid</td>
#       <td>1.99</td>
#     </tr>
#     <tr>
#       <td>App_340</td>
#       <td>ENTERTAINMENT</td>
#       <td>10000000</td>
#       <td>4.563754</td>
#       <td>113</td>
#       <td>Free</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>App_4631</td>
#       <td>TOOLS</td>
#       <td>10000000</td>
#       <td>4.585868</td>
#       <td>96</td>
#       <td>Free</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>App_4632</td>
#       <td>MUSIC</td>
#       <td>10000000</td>
#       <td>4.042055</td>
#       <td>471</td>
#       <td>Free</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>App_1175</td>
#       <td>ENTERTAINMENT</td>
#       <td>10000000</td>
#       <td>3.864221</td>
#       <td>773</td>
#       <td>Free</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>App_1782</td>
#       <td>BUSINESS</td>
#       <td>10000000</td>
#       <td>3.920817</td>
#       <td>1051</td>
#       <td>Free</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>App_2508</td>
#       <td>SHOPPING</td>
#       <td>10000000</td>
#       <td>3.990864</td>
#       <td>168</td>
#       <td>Paid</td>
#       <td>2.99</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 9. Correlation Matrix (Rating, Installs_log, Reviews, Size_MB, Price)
# ![correlation_table.png](attachment:correlation_table.png)

# %% [markdown]
# ### 10. Average Rating by Category
# ![avg_rating_by_category.png](attachment:avg_rating_by_category.png)

# %% [markdown]
# ### 11. Median Price by Category (Paid apps)
# ![median_price_by_category.png](attachment:median_price_by_category.png)

# %% [markdown]
# ### 12. App Size Distribution (MB)
# ![size_distribution.png](attachment:size_distribution.png)

# %% [markdown]
# ### 13. Content Rating Distribution
# ![content_rating_pie.png](attachment:content_rating_pie.png)

# %% [markdown]
# ### 14. Top Genres by Count
# ![top_genres.png](attachment:top_genres.png)

# %% [markdown]
# ### 15. Apps Updated per Month
# ![updates_per_month.png](attachment:updates_per_month.png)

# %% [markdown]
# ### 16. Log(Reviews) Distribution
# ![reviews_log_hist.png](attachment:reviews_log_hist.png)

# %% [markdown]
# ### 17. Rating vs App Size
# ![rating_vs_size.png](attachment:rating_vs_size.png)

# %% [markdown]
# ### 18. Median Installs by Category (Top 10)
# ![median_installs_by_category.png](attachment:median_installs_by_category.png)

# %% [markdown]
# ### 19. Log(Installs) Distribution by Category (Top 6)
# ![box_installs_by_category.png](attachment:box_installs_by_category.png)

# %% [markdown]
# ### 20. Paid Apps Count by Category
# ![paid_apps_by_category.png](attachment:paid_apps_by_category.png)

# %% [markdown]
# ### 21. Price Distribution (Paid Apps)
# ![price_distribution_paid.png](attachment:price_distribution_paid.png)

# %% [markdown]
# ### 22. Proportion of Apps with Rating > 4.5
# ![rating_above_4_5_pie.png](attachment:rating_above_4_5_pie.png)

# %% [markdown]
# ### 23. Top 15 Apps by Reviews
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>App</th>
#       <th>Category</th>
#       <th>Reviews</th>
#       <th>Rating</th>
#       <th>Installs</th>
#       <th>Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>App_4283</td>
#       <td>GAME</td>
#       <td>69103</td>
#       <td>3.908113</td>
#       <td>5000</td>
#       <td>Free</td>
#     </tr>
#     <tr>
#       <td>App_2396</td>
#       <td>FAMILY</td>
#       <td>64000</td>
#       <td>4.155613</td>
#       <td>10000000</td>
#       <td>Free</td>
#     </tr>
#     <tr>
#       <td>App_2522</td>
#       <td>TOOLS</td>
#       <td>55918</td>
#       <td>3.616898</td>
#       <td>1000000</td>
#       <td>Free</td>
#     </tr>
#     <tr>
#       <td>App_3766</td>
#       <td>LIFESTYLE</td>
#       <td>55613</td>
#       <td>3.809291</td>
#       <td>10000</td>
#       <td>Free</td>
#     </tr>
#     <tr>
#       <td>App_4502</td>
#       <td>TOOLS</td>
#       <td>48043</td>
#       <td>4.175230</td>
#       <td>100000</td>
#       <td>Free</td>
#     </tr>
#     <tr>
#       <td>App_4264</td>
#       <td>HEALTH</td>
#       <td>41977</td>
#       <td>4.344909</td>
#       <td>1000000</td>
#       <td>Free</td>
#     </tr>
#     <tr>
#       <td>App_4227</td>
#       <td>HEALTH</td>
#       <td>38600</td>
#       <td>4.054564</td>
#       <td>100000</td>
#       <td>Free</td>
#     </tr>
#     <tr>
#       <td>App_3651</td>
#       <td>TOOLS</td>
#       <td>34691</td>
#       <td>4.059206</td>
#       <td>100</td>
#       <td>Free</td>
#     </tr>
#     <tr>
#       <td>App_3303</td>
#       <td>TOOLS</td>
#       <td>33452</td>
#       <td>3.848386</td>
#       <td>100000</td>
#       <td>Free</td>
#     </tr>
#     <tr>
#       <td>App_1243</td>
#       <td>SHOPPING</td>
#       <td>31925</td>
#       <td>3.317982</td>
#       <td>100000</td>
#       <td>Free</td>
#     </tr>
#     <tr>
#       <td>App_3971</td>
#       <td>ENTERTAINMENT</td>
#       <td>28678</td>
#       <td>4.316882</td>
#       <td>50000</td>
#       <td>Free</td>
#     </tr>
#     <tr>
#       <td>App_1639</td>
#       <td>EDUCATION</td>
#       <td>26958</td>
#       <td>4.509224</td>
#       <td>50000</td>
#       <td>Free</td>
#     </tr>
#     <tr>
#       <td>App_316</td>
#       <td>TOOLS</td>
#       <td>25656</td>
#       <td>4.063319</td>
#       <td>50000</td>
#       <td>Paid</td>
#     </tr>
#     <tr>
#       <td>App_2284</td>
#       <td>GAME</td>
#       <td>23676</td>
#       <td>3.529594</td>
#       <td>50000</td>
#       <td>Free</td>
#     </tr>
#     <tr>
#       <td>App_4576</td>
#       <td>BUSINESS</td>
#       <td>22821</td>
#       <td>3.846291</td>
#       <td>1000000</td>
#       <td>Free</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 24. Average Installs by Content Rating
# ![avg_installs_by_content.png](attachment:avg_installs_by_content.png)

# %% [markdown]
# ### 25. Count by Minimum Android Version
# ![android_version_counts.png](attachment:android_version_counts.png)

# %% [markdown]
# ### 26. Reviews vs Rating
# ![reviews_vs_rating.png](attachment:reviews_vs_rating.png)

# %% [markdown]
# ### 27. Price Distribution (All Apps)
# ![price_distribution_all.png](attachment:price_distribution_all.png)

# %% [markdown]
# ### 28. Category Summary Statistics
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Category</th>
#       <th>apps_count</th>
#       <th>median_rating</th>
#       <th>median_installs</th>
#       <th>mean_size_mb</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>GAME</td>
#       <td>775</td>
#       <td>4.105219</td>
#       <td>50000.0</td>
#       <td>103.659804</td>
#     </tr>
#     <tr>
#       <td>TOOLS</td>
#       <td>712</td>
#       <td>4.077313</td>
#       <td>50000.0</td>
#       <td>100.694025</td>
#     </tr>
#     <tr>
#       <td>FAMILY</td>
#       <td>596</td>
#       <td>4.102831</td>
#       <td>50000.0</td>
#       <td>105.212008</td>
#     </tr>
#     <tr>
#       <td>EDUCATION</td>
#       <td>440</td>
#       <td>4.078613</td>
#       <td>50000.0</td>
#       <td>89.562066</td>
#     </tr>
#     <tr>
#       <td>ENTERTAINMENT</td>
#       <td>428</td>
#       <td>4.042461</td>
#       <td>50000.0</td>
#       <td>96.931450</td>
#     </tr>
#     <tr>
#       <td>LIFESTYLE</td>
#       <td>413</td>
#       <td>4.119724</td>
#       <td>50000.0</td>
#       <td>100.869490</td>
#     </tr>
#     <tr>
#       <td>SHOPPING</td>
#       <td>355</td>
#       <td>4.107220</td>
#       <td>50000.0</td>
#       <td>105.258040</td>
#     </tr>
#     <tr>
#       <td>HEALTH</td>
#       <td>322</td>
#       <td>4.102801</td>
#       <td>50000.0</td>
#       <td>108.640332</td>
#     </tr>
#     <tr>
#       <td>BUSINESS</td>
#       <td>284</td>
#       <td>4.065213</td>
#       <td>10000.0</td>
#       <td>93.752397</td>
#     </tr>
#     <tr>
#       <td>FINANCE</td>
#       <td>281</td>
#       <td>4.116371</td>
#       <td>50000.0</td>
#       <td>109.619142</td>
#     </tr>
#     <tr>
#       <td>MUSIC</td>
#       <td>256</td>
#       <td>4.088035</td>
#       <td>50000.0</td>
#       <td>115.267546</td>
#     </tr>
#     <tr>
#       <td>PRODUCTIVITY</td>
#       <td>138</td>
#       <td>4.042025</td>
#       <td>50000.0</td>
#       <td>91.800480</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 29. Median Rating by Genre and Content Rating
# ![median_rating_genre_content.png](attachment:median_rating_genre_content.png)

# %% [markdown]
# ### 30. Cumulative Installs of Top 50 Apps
# ![cumulative_installs_top50.png](attachment:cumulative_installs_top50.png)

# %% [markdown]
# ### 31. Counts by Current_Version
# ![current_version_counts.png](attachment:current_version_counts.png)

# %% [markdown]
# ### 32. Top 10 Most Expensive Paid Apps
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>App</th>
#       <th>Category</th>
#       <th>Price_USD</th>
#       <th>Rating</th>
#       <th>Installs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>App_1229</td>
#       <td>TOOLS</td>
#       <td>99.99</td>
#       <td>3.590567</td>
#       <td>5000</td>
#     </tr>
#     <tr>
#       <td>App_3832</td>
#       <td>SHOPPING</td>
#       <td>99.99</td>
#       <td>4.426303</td>
#       <td>100000</td>
#     </tr>
#     <tr>
#       <td>App_257</td>
#       <td>HEALTH</td>
#       <td>99.99</td>
#       <td>4.328473</td>
#       <td>10000</td>
#     </tr>
#     <tr>
#       <td>App_4548</td>
#       <td>HEALTH</td>
#       <td>99.99</td>
#       <td>4.606665</td>
#       <td>1000</td>
#     </tr>
#     <tr>
#       <td>App_3589</td>
#       <td>FAMILY</td>
#       <td>99.99</td>
#       <td>4.346666</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <td>App_1333</td>
#       <td>PRODUCTIVITY</td>
#       <td>99.99</td>
#       <td>4.413345</td>
#       <td>1000000</td>
#     </tr>
#     <tr>
#       <td>App_3496</td>
#       <td>SHOPPING</td>
#       <td>99.99</td>
#       <td>3.494469</td>
#       <td>100000</td>
#     </tr>
#     <tr>
#       <td>App_3152</td>
#       <td>FINANCE</td>
#       <td>99.99</td>
#       <td>4.370056</td>
#       <td>50000</td>
#     </tr>
#     <tr>
#       <td>App_4244</td>
#       <td>BUSINESS</td>
#       <td>99.99</td>
#       <td>4.322964</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <td>App_4521</td>
#       <td>LIFESTYLE</td>
#       <td>99.99</td>
#       <td>3.658091</td>
#       <td>50000</td>
#     </tr>
#   </tbody>
# </table>
